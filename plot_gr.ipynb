# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
a = np.loadtxt('./gr.dat')
print(a)
# Out:
# [[0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00]
#  [1.0000e-03 0.0000e+00 0.0000e+00 0.0000e+00]
#  [2.0000e-03 0.0000e+00 0.0000e+00 0.0000e+00]
#  ...
#  [5.5998e+01 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.5999e+01 0.0000e+00 0.0000e+00 0.0000e+00]
#  [5.6000e+01 0.0000e+00 0.0000e+00 0.0000e+00]]

# %%
fig1 = plt.figure()

ax = plt.gca()
#plt.scatter(a[:,0], a[:,1]/10, c='red', label='3 million')#per 10step
#plt.scatter(a[:,0], a[:,2]/10, c='blue', label='15 million')
plt.scatter(a[:,0], a[:,1]/10, c='green', label='30_0 million') 
plt.scatter(a[:,0], a[:,2]/10, c='yellow', label='30_1 million') 
plt.scatter(a[:,0], a[:,3]/10, c='purple', label='30_2 million')
